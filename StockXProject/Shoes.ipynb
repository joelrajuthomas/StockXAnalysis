# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#which state the most shoes and what type, which states spend the most over retail price, divide into color

# %%
shoes = pd.read_csv("shoe_data.csv")

# %%
shoes['primary_color'] = 'n/a'
shoes['secondary_color'] = 'n/a'
shoes['tertiary_color'] = 'n/a'

# %%
#unique sneaker_name values
shoes.sneaker_name.unique()
# Out:
# array(['Adidas-Yeezy-Boost-350-Low-V2-Beluga',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Copper',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Green',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Red',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-White',
#        'Adidas-Yeezy-Boost-350-V2-Cream-White',
#        'Adidas-Yeezy-Boost-350-V2-Zebra',
#        'Adidas-Yeezy-Boost-350-Low-Moonrock', 'Nike-Air-Max-90-Off-White',
#        'Nike-Air-Presto-Off-White', 'Nike-Air-VaporMax-Off-White',
#        'Air-Jordan-1-Retro-High-Off-White-Chicago',
#        'Nike-Blazer-Mid-Off-White',
#        'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016',
#        'Adidas-Yeezy-Boost-350-Low-Oxford-Tan',
#        'Adidas-Yeezy-Boost-350-Low-Turtledove',
#        'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015',
#        'Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow',
# ...

# %%
#Adidas-Yeezy-Boost-350-Low-V2-Beluga
#primary_color: grey
#secondary_color: orange
#tertiary_color: dark_grey
#498 sales
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-V2-Beluga'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-V2-Beluga'),'secondary_color'] = 'orange'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-V2-Beluga'),'tertiary_color'] = 'grey'
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-V2-Beluga')]
#fun fact: gray is american-english. grey is british-english

#Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
#primary_color: black
#secondary_color: copper
#tertiary_color: n/a
#225 sales
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Copper'), 'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Copper'), 'secondary_color'] = 'copper'
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Copper'), 'tertiary_color'] = 'n/a'

#Adidas-Yeezy-Boost-350-V2-Core-Black-Green
#primary_color: black
#secondary_color: green
#tertiary_color: n/a
#196 sales
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Green'), 'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Green'), 'secondary_color'] = 'green'
shoes.loc[shoes['sneaker_name'].str.contains('V2-Core-Black-Green'), 'tertiary_color'] = 'n/a'
#shoes[shoes['sneaker_name'].str.contains('V2-Core-Black-Green')]
#shoes[shoes['secondary_color'].str.contains('green')]
#more like olive rather than green

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'secondary_color'] = 'red'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'tertiary_color'] = 'n/a'
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red')]

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017'),'tertiary_color'] = 'red'
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red')]

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-White'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-White'),'tertiary_color'] = 'n/a'
# shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-White')]

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'tertiary_color'] = 'white'
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White')]

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White'),'tertiary_color'] = 'red'
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White')]

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Zebra'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Zebra'),'secondary_color'] = 'dark_grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Zebra'),'tertiary_color'] = 'red'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016'),'tertiary_color'] = 'black'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Oxford-Tan'),'primary_color'] = 'brown'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Oxford-Tan'),'secondary_color'] = 'brown'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Oxford-Tan'),'tertiary_color'] = 'brown'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Turtledove'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Turtledove'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Turtledove'),'tertiary_color'] = 'n/a'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015'),'tertiary_color'] = 'black'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow'),'primary_color'] = 'neon_yellow'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow'),'tertiary_color'] = 'red'

shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Moonrock'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Moonrock'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-Low-Moonrock'),'tertiary_color'] = 'grey'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-90-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-90-Off-White'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-90-Off-White'),'tertiary_color'] = 'blue'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White'),'tertiary_color'] = 'red'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White'),'tertiary_color'] = 'grey'


shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-Chicago'),'primary_color'] = 'red'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-Chicago'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-Chicago'),'tertiary_color'] = 'black'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White'),'tertiary_color'] = 'grey'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White'),'tertiary_color'] = 'n/a'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White'),'tertiary_color'] = 'black'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100'),'secondary_color'] = 'silver'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100'),'tertiary_color'] = 'n/a'


shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-React-Hyperdunk-2017-Flyknit-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-React-Hyperdunk-2017-Flyknit-Off-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-React-Hyperdunk-2017-Flyknit-Off-White'),'tertiary_color'] = 'black'

shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White'),'tertiary_color'] = 'n/a'


#Nike-Air-Max-90-Off-White-Desert-Ore'
#primary_color: brown
#secondary_color: orange
#tertiary_color: n/a
#649 sales
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Desert-Ore'), 'primary_color'] = 'brown'
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Desert-Ore'), 'secondary_color'] = 'orange'
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Desert-Ore'), 'tertiary_color'] = 'n/a'
  
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Black'), 'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Black'), 'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.contains('Nike-Air-Max-90-Off-White-Black'), 'tertiary_color'] = 'orange'
 
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static-Reflective'), 'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static-Reflective'), 'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static-Reflective'), 'tertiary_color'] = 'transparent'
 
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static'), 'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static'), 'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.contains('adidas-Yeezy-Boost-350-V2-Static'), 'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'secondary_color'] = 'red'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red'),'tertiary_color'] = 'n/a'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-Red')]
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Black-White'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Black-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Black-White'),'tertiary_color'] = 'orange'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Volt'),'primary_color'] = 'neon_yellow'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Volt'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Force-1-Low-Off-White-Volt'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Pink'),'primary_color'] = 'pink'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Pink'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Pink'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Black-Silver'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Black-Silver'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Off-White-Black-Silver'),'tertiary_color'] = 'white'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Black'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Black'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Black'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Menta'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Menta'),'secondary_color'] = 'n/a'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Menta'),'tertiary_color'] = 'iridescent'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Wolf-Grey'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Wolf-Grey'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Wolf-Grey'),'tertiary_color'] = 'white'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Sesame'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Sesame'),'secondary_color'] = 'gum'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Sesame'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Grim-Reaper'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Grim-Reaper'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-Grim-Reaper'),'tertiary_color'] = 'white'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-All-Hallows-Eve'),'primary_color'] = 'brown'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-All-Hallows-Eve'),'secondary_color'] = 'orange'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Blazer-Mid-Off-White-All-Hallows-Eve'),'tertiary_color'] = 'black'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Elemental-Rose-Queen'),'primary_color'] = 'pink'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Elemental-Rose-Queen'),'secondary_color'] = 'purple'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Max-97-Off-White-Elemental-Rose-Queen'),'tertiary_color'] = 'black'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('adidas-Yeezy-Boost-350-V2-Butter'),'primary_color'] = 'yellow'
shoes.loc[shoes['sneaker_name'].str.strip()==('adidas-Yeezy-Boost-350-V2-Butter'),'secondary_color'] = 'yellow'
shoes.loc[shoes['sneaker_name'].str.strip()==('adidas-Yeezy-Boost-350-V2-Butter'),'tertiary_color'] = 'yellow'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange'),'primary_color'] = 'orange'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange'),'tertiary_color'] = 'iridescent'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Black'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Black'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Zoom-Fly-Mercurial-Off-White-Black'),'tertiary_color'] = 'iridescent'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-White-2018'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-White-2018'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-White-2018'),'tertiary_color'] = 'grey'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-Black-2018'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-Black-2018'),'secondary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-Presto-Off-White-Black-2018'),'tertiary_color'] = 'white'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-University-Blue'),'primary_color'] = 'blue'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-University-Blue'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-University-Blue'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-Black'),'primary_color'] = 'black'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-Black'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-Black'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-White'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-White'),'secondary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Air-Jordan-1-Retro-High-Off-White-White'),'tertiary_color'] = 'white'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-2018'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-2018'),'secondary_color'] = 'transparent'
shoes.loc[shoes['sneaker_name'].str.strip()==('Nike-Air-VaporMax-Off-White-2018'),'tertiary_color'] = 'n/a'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Blue-Tint'),'primary_color'] = 'white'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Blue-Tint'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Blue-Tint'),'tertiary_color'] = 'red'
 
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Beluga-2pt0'),'primary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Beluga-2pt0'),'secondary_color'] = 'grey'
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Beluga-2pt0'),'tertiary_color'] = 'orange'

# %%
#shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Core-Black-White')]
#shoes['shoe_size'].mean()


shoes['sale_price'] = shoes['sale_price'].replace({'\$': '', ',': ''}, regex=True)
shoes['retail_price'] = shoes['retail_price'].replace({'\$': '', ',': ''}, regex=True)
shoes = shoes.astype({"sale_price": float, "retail_price": float})

# %%
shoes.loc[shoes['sneaker_name'].str.strip()==('Adidas-Yeezy-Boost-350-V2-Cream-White')].mean()
# Out:
# sale_price      288.708805
# retail_price    220.000000
# shoe_size         9.230900
# dtype: float64

# %%
shoes.head()
# Out:
#   order_date   brand                                   sneaker_name  \
# 0     9/1/17   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1     9/1/17   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2     9/1/17   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3     9/1/17   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4     9/1/17   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    sale_price  retail_price release_date  shoe_size  buyer_region  \
# 0      1097.0         220.0      9/24/16       11.0    California
# 1       685.0         220.0     11/23/16       11.0    California
# 2       690.0         220.0     11/23/16       11.0    California
# 3      1075.0         220.0     11/23/16       11.5      Kentucky
# 4       828.0         220.0      2/11/17       11.0  Rhode Island
#
#   primary_color secondary_color tertiary_color
# 0          grey          orange           grey
# 1         black          copper            n/a
# ...

# %%
shoes.loc[shoes['primary_color'].str.strip()==('blue')]
bruh = shoes['buyer_region'].value_counts()[:10]

# %%
state_sales = sns.countplot(y="buyer_region", data=shoes, order=shoes.buyer_region.value_counts().iloc[:10].index, palette="bright")

# %%
shoes.sale_price.mean()
# Out:
# 446.63471927648163

# %%
shoes.retail_price.mean()
# Out:
# 208.613589979591

# %%
shoes['difference']= shoes['sale_price'] - shoes['retail_price']
#makes new column for sale price
shoes.head()
# Out:
#   order_date   brand                                   sneaker_name  \
# 0     9/1/17   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1     9/1/17   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2     9/1/17   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3     9/1/17   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4     9/1/17   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    sale_price  retail_price release_date  shoe_size  buyer_region  \
# 0      1097.0         220.0      9/24/16       11.0    California
# 1       685.0         220.0     11/23/16       11.0    California
# 2       690.0         220.0     11/23/16       11.0    California
# 3      1075.0         220.0     11/23/16       11.5      Kentucky
# 4       828.0         220.0      2/11/17       11.0  Rhode Island
#
#   primary_color secondary_color tertiary_color  difference
# 0          grey          orange           grey       877.0
# ...

# %%
shoes[shoes['difference'] < 0] #returns all the rows
# Out:
#       order_date   brand                                  sneaker_name  \
# 50022    9/25/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50200    9/26/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50418    9/27/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50436    9/27/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50447    9/27/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50464    9/27/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50629    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50635    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50642    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50644    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50701    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# 50702    9/28/18   Yeezy         Adidas-Yeezy-Boost-350-V2-Cream-White
# ...

# %%
shoes[shoes['difference'] < 0].sneaker_name.unique()
# Out:
# array(['Adidas-Yeezy-Boost-350-V2-Cream-White',
#        'adidas-Yeezy-Boost-350-V2-Butter',
#        'Adidas-Yeezy-Boost-350-V2-Sesame',
#        'Adidas-Yeezy-Boost-350-V2-Beluga-2pt0',
#        'Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow'], dtype=object)

# %%
shoes2 = shoes.groupby(['buyer_region']).difference.mean().sort_values(ascending=False).to_frame()
shoes2
# Out:
#                       difference
# buyer_region
# Delaware              297.651369
# Hawaii                284.449086
# Nevada                278.811392
# California            271.426637
# Oregon                263.409842
# Iowa                  253.843478
# Vermont               251.345238
# Kentucky              249.743852
# District of Columbia  244.003690
# Virginia              242.092809
# Arizona               240.361946
# New Jersey            240.307415
# Utah                  240.075556
# Florida               237.872334
# Washington            235.368760
# New York              233.629470
# Minnesota             228.594483
# Alaska                228.524590
# Oklahoma              226.201456
# Colorado              224.539832
# Wisconsin             224.364286
# Maryland              224.177540
# Georgia               221.353738
# Illinois              219.745108
# Massachusetts         219.648639
# Ohio                  218.669841
# South Carolina        216.901754
# ...

# %%
shoes3 = shoes.groupby(['buyer_region']).difference.count().sort_values(ascending=False).to_frame()
shoes3
# Out:
#                       difference
# buyer_region
# California                 19349
# New York                   16525
# Oregon                      7681
# Florida                     6376
# Texas                       5876
# New Jersey                  4720
# Illinois                    3782
# Pennsylvania                3109
# Massachusetts               2903
# Michigan                    2762
# Virginia                    2058
# Ohio                        1890
# Maryland                    1870
# Washington                  1863
# Georgia                     1846
# Arizona                     1398
# North Carolina              1344
# Delaware                    1242
# Connecticut                 1110
# Indiana                     1026
# Colorado                     954
# Wisconsin                    840
# Nevada                       790
# Tennessee                    731
# Minnesota                    725
# Missouri                     660
# South Carolina               570
# ...

# %%
shoes2 = shoes2.reset_index()
shoes3 = shoes3.reset_index()
shoes2.head()
# Out:
#   buyer_region  difference
# 0     Delaware  297.651369
# 1       Hawaii  284.449086
# 2       Nevada  278.811392
# 3   California  271.426637
# 4       Oregon  263.409842

# %%
shoes4 = pd.merge(shoes2, shoes3, on='buyer_region', how='inner')

# %%
shoes4 = shoes4.rename(columns={ "difference_x":"difference", "difference_y": "sales_count"})
#this shows the average difference in price and also gives how many from are data set are included in each states sales.

# %%
shoes4.head()
# Out:
#   buyer_region  difference  sales_count
# 0     Delaware  297.651369         1242
# 1       Hawaii  284.449086          383
# 2       Nevada  278.811392          790
# 3   California  271.426637        19349
# 4       Oregon  263.409842         7681

# %%
shoes4['percent_sales'] = shoes4['sales_count']/99956 * 100

# %%
shoes5= shoes4.nlargest(5, 'sales_count')
shoes5
# Out:
#    buyer_region  difference  sales_count  percent_sales
# 3    California  271.426637        19349      19.357517
# 15     New York  233.629470        16525      16.532274
# 4        Oregon  263.409842         7681       7.684381
# 13      Florida  237.872334         6376       6.378807
# 35        Texas  207.015997         5876       5.878587

# %%
df2 = {'buyer_region': "Other States", 'difference': "n/a", 'sales_count': 44149, 'percent_sales': 44.168434}

# %%
shoes5 = shoes5.append(df2, ignore_index=True)
shoes5
# Out:
#    buyer_region difference  sales_count  percent_sales
# 0    California    271.427        19349      19.357517
# 1      New York    233.629        16525      16.532274
# 2        Oregon     263.41         7681       7.684381
# 3       Florida    237.872         6376       6.378807
# 4         Texas    207.016         5876       5.878587
# 5  Other States        n/a        44149      44.168434

# %%
shoes5.plot(kind='pie', y = 'percent_sales', labels=shoes5['buyer_region'], autopct='%1.1f%%', figsize=(8,8))
